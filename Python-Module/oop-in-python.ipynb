# %% [markdown]
# ## Object Oriented Programming

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
pi = 3.142

# %% [markdown]
# Object = State + Behaviour
#
# State:
# - int
#
# Behaviour
# - can peform calculation (+, -, /, %)
# - can define constants (pi)

# %%
"Hello"
# Out:
# 'Hello'

# %%
type("Hello")
# Out:
# str

# %%
sugarlevels = []

# %% [markdown]
# Hello = Object
# Object = State + Behaviour
#
# State:
# - str
#
# Behaviour:
# - can defining variable names
# - define any text content in our code
# - define docstrings that explain functions
#
# N/B - Everything in python is an object

# %% [markdown]
# **Creating Our First Class Customer**

# %%
class CustomerGikosh:
    """A class that will be a blueprint for all the customers in Gikosh
    It will contain the following states and behaviours:
    - States: name, rewards_number, email, phone_number
    - Behaviours: make_purcase, return_purchase, order_online, cancel_order"""

    # "__init__" is a dunder function that we use to initialize the states for the customer class. This instantiates the states of the code. The double underscore is what makes it a dunder function.
    # self here will allow as to add multiple name, reward numbers, emails and phone numbers
    # this way every customer will have their own name, rewards_number, email, phone_number

    # Here the name, rewards_number etc. all states are our `attributes`
    # Our make_purchase, return_purchase, order_online etc. are our `methods`

    def __init__(self, name, rewards_number, email, phone_number):
        self.name = name
        self.rewards_number = rewards_number
        self.email = email
        self.phone_number = phone_number

    def make_purchase(self):
        print(f"Thank you {self.name} for your purchase. You have earned 200 points under reward number {self.rewards_number}")

    def return_purchase(self):
        print("Return of Purchase for order 092 is approved. You will recieve a refund in 3-5 business days.")

    def order_online(self):
        print(f"Thank you for your online order {self.name}.")

    def cancel_order(self):
        print(f"Your order for {self.name} has been cancelled.")

# %%
cust0ne = CustomerGikosh("James", 1010, "mutungajames334@gmail.com", "254717721596")

# %%
# View all our customer one details
print(cust0ne.name)
print(cust0ne.rewards_number)
# Out:
# James
# 1010

# %%
cust0ne.return_purchase()
# Out:
# Return of Purchase for order 092 is approved. You will recieve a refund in 3-5 business days.

# %%
dir(cust0ne)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'cancel_order',
#  'email',
#  'make_purchase',
#  'name',
#  'order_online',
#  'phone_number',
#  'return_purchase',
#  'rewards_number']

# %%
samp_list = [1, 2, 3, 3, 5]

# %%
dir(samp_list)

# This will give us every method that we can use for the attributes in the samp_list
# so for example we can do `def __doc__()` for samp_list or .insert, .pop or .remove for the attributes in samp_list
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# **Create your own class before tomorrow's class due: 15/09/26**

# %%
class MPESAcustomer:

    """A class that will be a blueprint for all MPESA customers
        It will contain the following states and behaviours:
        - States: name, phone_number, account_balance, fuliza_limit
        - Behaviours: check_account_balance, buy_goods, send_money_request, check_fuliza_limit"""

    def __init__(self, name, phone_number, account_balance, fuliza_limit):
        self.name = name
        self.phone_number = phone_number
        self.account_balance = account_balance
        self.fuliza_limit = fuliza_limit

    def send_money_request(self):
        amount = input("Enter Amount You would like to request: ")
        print(f"Thank you {self.name} for requesting {amount}KES from Patrick Kimani.")

    def buy_goods(self):
        goods_amount = input("Enter Amount You would like to send: ")
        print(f"Sending {goods_amount}KES to Kipkemboi's barber shop.")

    def check_account_balance(self):
        print(f"Dear {self.name}, Your current MPESA Balance is {self.account_balance}KES for {self.phone_number}")
                
    def check_fuliza_limit(self):
        print(f"Dear {self.name}, your current outstanding fuliza limit is {self.fuliza_limit}KES")

# %%
customer1 = MPESAcustomer("James Mutunga", 254717721596, 499984, 0)

# %%
print(customer1.name)
print(customer1.account_balance)
print(customer1.fuliza_limit)
print(customer1.phone_number)
# Out:
# James Mutunga
# 499984
# 0
# 254717721596

# %%
customer1.check_account_balance()
# Out:
# Dear James Mutunga, Your current MPESA Balance is 499984KES for 254717721596

# %%
customer1.buy_goods()
# Out:
# Sending 300KES to Kipkemboi's barber shop.

# %%
customer1.send_money_request()
# Out:
# Thank you James Mutunga for requesting 6000KES from Patrick Kimani.

# %%
customer1.check_fuliza_limit()
# Out:
# Dear James Mutunga, your current outstanding fuliza limit is 0KES

# %% [markdown]
# > Dennis' example on Inheritance & Polymorphism
# ---

# %%
class Animal:
    """This is a an animal class and it contains the following states and behaviours
    States: name
    Behaviours: speak"""

    def __int__(self, name):
        self.name = name

    def speak(self):
        print("This animal makes a sound")

class Dog:
    """This class dog contains the following states and behaviours
    States: name
    Behaviours: speak"""

    def speak(self):
        print("Dog barks!")

class Cat(Animal):
    """This cat class inherits from the animal class this means it contains 
    both the states from the animal class and states that we will define inside it
    States: name
    Behaviour: speak"""

    def speak(self):
        print("Cat meows!")


animals = [Dog(), Cat()]
for animal in animals:
    animal.speak()
# Out:
# Dog barks!
# Cat meows!

# %% [markdown]
# ## Inheritance

# %%
class BankAccount:
    """This is a class used to instantiate Bank Customers
    State : balance
    Behaviour : withdraw
    """

    def __int__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        self.balance -= amount

# An empty class inheriting from the BankAccount Class

class SavingAccount(BankAccount):
    # Constructor for Savings Account with additional arguments \
    def __init__(self, balance, interest_rate):
        # Call the Parent Constructor using ClassName.__init__()
        # Self is a savings account but also a BankAccount
        BankAccount.__int__(self, balance)

        # Add More functionality
        self.interest_rate = interest_rate

        # compound interest = 1 + interest rate raised to the power of (???)
    def compute_interest(self, n_periods = 1):
        return self.balance * ((1 + self.interest_rate) ** n_periods -1)

# %%
class BankAccount:

    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        self.balance -= amount

class SavingAccount(BankAccount):
    def __init__(self, balance, interest_rate):
        BankAccount.__init__(self, balance)

        self.interest_rate = interest_rate

# %%
acct = SavingAccount(4000, 0.03)
acct.interest_rate
acct.balance
# Out:
# 4000

# %%
acct.compute_interest(4)
# Out:
# 502.03524000000056

# %%
acct.

# %% [markdown]
# **Class Level Attributes**

# %% [markdown]
# **Instance Level Attributes**

# %%
class Employee:
    # Define a class level attribute for the min salary of househelps following the govt directive
    MIN_SALARY = 20000

    def __init__(self, name, salary):
        self.name = name

        # Add logic that no employee earns less than 20000
        if salary >= 20000:
            self.salary = salary
        else:
            self.salary = Employee.MIN_SALARY

# %%
emp1 = Employee("John", 40000)
emp1.salary
# Out:
# 40000

# %%
emp2 = Employee("Manasseh", 15000)
emp2.salary
# Out:
# 20000

# %%
class BankAccount:
    """This is a class used to instantiate Bank Customers
    State : balance"""

    MIN_BALANCE = 1000
    def __int__(self, balance):
        if balance >= BankAccount.MIN_BALANCE:
            self.balance
        else:
            self.balance = BankAccount.MIN_BALANCE

    def withdraw(self, amount):
        self.balance -= amount

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient

# 1. Load the secret password
load_dotenv()
uri = os.getenv("MONGO_URI")

# 2. Connect to the Client (The Cluster)
client = MongoClient(uri)

# 3. Access the Database (e.g., "school")
# If it doesn't exist, Mongo creates it automatically when you insert data.
db = client["school"]

# 4. Access the Collection (e.g., "students")
students = db["students"]

# 5. Test the connection
try:
    client.admin.command('ping')
    print("Successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# LifetimeTimeout                           Traceback (most recent call last)
# File ~\desktop\my-python-class\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:99, in _SrvResolver.get_options(self)
#      98 try:
# ---> 99     results = _resolve(self.__fqdn, "TXT", lifetime=self.__connect_timeout)
#     100 except (resolver.NoAnswer, resolver.NXDOMAIN):
#     101     # No TXT records
#
# File ~\desktop\my-python-class\venv\Lib\site-packages\pymongo\synchronous\srv_resolver.py:46, in _resolve(*args, **kwargs)
#      44     from dns import resolver
# ---> 46     return resolver.resolve(*args, **kwargs)
#      47 else:
#
# File ~\desktop\my-python-class\venv\Lib\site-packages\dns\resolver.py:1572, in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1563 """Query nameservers to find the answer to the question.
#    1564
# ...
